# %% [markdown]
# # **AntiMicrobial Resistance Prediction from SNPs**

# %% [markdown]
# This notebook contains the end-to-end Custom 1D CNN implementation of **AMR Prediction from SNPs** project for the Ceftazidime (CTZ) antibiotic. Feel free to use/customise the model architecture.

# %% [markdown]
# #**Setup & Imports**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers, Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, roc_curve, accuracy_score, cohen_kappa_score, matthews_corrcoef
import seaborn as sns

# --- Configuration ---
SNP_MATRIX_FILE = "/content/drive/MyDrive/AMR/Giessen_dataset/cip_ctx_ctz_gen_multi_data.csv"
PHENOTYPES_FILE = "/content/drive/MyDrive/AMR/Giessen_dataset/cip_ctx_ctz_gen_pheno.csv"
TARGET_ANTIBIOTIC = "CTZ"
# Model Hyperparameters for 1D CNN
VOCAB_SIZE = 5      # N:0, A:1, G:2, C:3, T:4
EMBEDDING_DIM = 64  # Dimension for the embedding layer (can be tuned)
MAX_SEQ_LEN = None  # Will be determined from data
DROPOUT_RATE = 0.45  # Regularization for Dense layers
CONV_DROPOUT_RATE = 0.15 # Regularization for Conv layers

# Training Hyperparameters
EPOCHS = 150 # Can be tuned
BATCH_SIZE = 32 # Can be tuned
LEARNING_RATE = 1e-3 # Can be tuned
VALIDATION_SPLIT = 0.15
TEST_SPLIT = 0.2

# Seed for reproducibility (Can be shuffled)
tf.random.set_seed(42)
np.random.seed(42)

# Checking for GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"Using GPU: {gpus[0].name}")
    except RuntimeError as e:
        print(e)
else:
    print("Using CPU")
# Out:
# Using GPU: /physical_device:GPU:0

# %% [markdown]
# # **Initial Preprocessing**

# %%
print("\n--- Loading and Preprocessing Data for 1D CNN ---")
try:
    snp_df_raw = pd.read_csv(SNP_MATRIX_FILE)
    pheno_df = pd.read_csv(PHENOTYPES_FILE)
except FileNotFoundError:
    print(f"ERROR: Ensure '{SNP_MATRIX_FILE}' and '{PHENOTYPES_FILE}' are in the same directory.")
    exit()

print(f"Raw SNP matrix shape: {snp_df_raw.shape}")
print(f"Phenotypes shape: {pheno_df.shape}")

# Setting 'prename' as index for easy merging
snp_df = snp_df_raw.set_index('prename')
pheno_df = pheno_df.set_index('prename')

# Merging SNP data with phenotype data
merged_df = snp_df.join(pheno_df[TARGET_ANTIBIOTIC], how='inner')
print(f"Merged data shape: {merged_df.shape}")

# Handling potential NaN values
merged_df = merged_df.dropna(subset=[TARGET_ANTIBIOTIC])
# Filling NaNs in SNP features with 0 (assuming this corresponds to 'N' or unknown)
merged_df = merged_df.fillna(0)
print(f"Shape after dropping NaNs in target and filling NaNs in features: {merged_df.shape}")

# Separating features (SNPs) and labels
labels = merged_df[TARGET_ANTIBIOTIC].values.astype(np.int32)
features_df = merged_df.drop(columns=[TARGET_ANTIBIOTIC])

snp_position_names = features_df.columns.tolist()

# --- Integer Encoding (Data is already in this format 0-4) ---
X_integer_encoded = features_df.values.astype(np.int32)

MAX_SEQ_LEN = X_integer_encoded.shape[1] # This is the number of SNP positions
print(f"Sequence length (number of SNPs): {MAX_SEQ_LEN}")
print(f"Labels shape: {labels.shape}")
print(f"Class distribution: Resistant (1): {np.sum(labels == 1)}, Susceptible (0): {np.sum(labels == 0)}")
if np.any(X_integer_encoded >= VOCAB_SIZE) or np.any(X_integer_encoded < 0):
    print("WARNING: SNP values out of expected range [0, VOCAB_SIZE-1]. Check encoding.")
# Out:
# --- Loading and Preprocessing Data for 1D CNN ---
# Raw SNP matrix shape: (809, 60937)
# Phenotypes shape: (809, 5)
# Merged data shape: (809, 60937)
# Shape after dropping NaNs in target and filling NaNs in features: (809, 60937)
# Sequence length (number of SNPs): 60936
# Labels shape: (809,)
# Class distribution: Resistant (1): 276, Susceptible (0): 533

# %% [markdown]
# # **Data Splitting**

# %%
print("\n--- Splitting Data ---")

X_train, X_test, y_train, y_test = train_test_split(
    X_integer_encoded, labels,
    test_size=TEST_SPLIT,
    random_state=42,
    stratify=labels
)

print(f"Training samples: {X_train.shape[0]}, Sequence Length: {X_train.shape[1]}")
print(f"Test samples: {X_test.shape[0]}")
# Out:
# --- Splitting Data ---
# Training samples: 647, Sequence Length: 60936
# Test samples: 162

# %% [markdown]
# # **1D CNN Model Definition**

# %%
print("\n--- Defining the 1D CNN Model (Extended to 6 Convolutional Blocks) ---")

def build_cnn1d_model_extended(maxlen, vocab_size, embed_dim, num_classes_binary, conv_dropout_rate, dense_dropout_rate):
    inputs = keras.Input(shape=(maxlen,), name="snp_input_sequence")

    # Embedding layer
    x = layers.Embedding(input_dim=vocab_size,
                         output_dim=embed_dim,
                         input_length=maxlen,
                         name="embedding_layer")(inputs)
    # x = layers.SpatialDropout1D(0.15)(x) # Optional: Dropout after embedding, slightly increased (I don't recommend it!)

    # Convolutional blocks - Doubled
    # Block 1
    x = layers.Conv1D(filters=128, kernel_size=7, padding="same",
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_1")(x)
    x = layers.BatchNormalization(name="batchnorm_1")(x)
    x = layers.Activation("relu", name="relu_1")(x)
    x = layers.MaxPooling1D(pool_size=2, name="maxpool_1")(x) # Adjusted pool_size slightly
    # x = layers.Dropout(conv_dropout_rate, name="conv_dropout_1")(x)    ## Worked well after commenting out this layer

    # Block 2
    x = layers.Conv1D(filters=128, kernel_size=7, padding="same", # Repeating similar block
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_2")(x)
    x = layers.BatchNormalization(name="batchnorm_2")(x)
    x = layers.Activation("relu", name="relu_2")(x)
    x = layers.MaxPooling1D(pool_size=2, name="maxpool_2")(x) # Adjusted pool_size
    # x = layers.Dropout(conv_dropout_rate, name="conv_dropout_2")(x)    ## Worked well after commenting out this layer

    # Block 3
    x = layers.Conv1D(filters=64, kernel_size=5, padding="same",
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_3")(x)
    x = layers.BatchNormalization(name="batchnorm_3")(x)
    x = layers.Activation("relu", name="relu_3")(x)
    x = layers.MaxPooling1D(pool_size=2, name="maxpool_3")(x) # Adjusted pool_size
    # x = layers.Dropout(conv_dropout_rate, name="conv_dropout_3")(x)    ## Worked well after commenting out this layer

    # Block 4
    x = layers.Conv1D(filters=64, kernel_size=5, padding="same", # Repeating similar block
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_4")(x)
    x = layers.BatchNormalization(name="batchnorm_4")(x)
    x = layers.Activation("relu", name="relu_4")(x)
    x = layers.MaxPooling1D(pool_size=2, name="maxpool_4")(x) # Adjusted pool_size
    # x = layers.Dropout(conv_dropout_rate, name="conv_dropout_4")(x)    ## Worked well after commenting out this layer

    # Block 5
    x = layers.Conv1D(filters=32, kernel_size=3, padding="same",
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_5")(x)
    x = layers.BatchNormalization(name="batchnorm_5")(x)
    x = layers.Activation("relu", name="relu_5")(x)
    # No MaxPooling after the last few conv blocks sometimes helps retain info before GlobalPooling
    x = layers.Dropout(conv_dropout_rate, name="conv_dropout_5")(x)


    # Block 6
    x = layers.Conv1D(filters=32, kernel_size=3, padding="same",
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_6")(x)
    x = layers.BatchNormalization(name="batchnorm_6")(x)
    x = layers.Activation("relu", name="relu_6")(x)
    # No MaxPooling here either
    x = layers.Dropout(conv_dropout_rate, name="conv_dropout_6")(x)


    # Flatten or Pool for Dense layers
    x = layers.GlobalMaxPooling1D(name="global_max_pooling")(x)         ## GlobalMaxPooling worked better than flattening and GlobalAvgPooling
    # x = layers.GlobalAveragePooling1D(name="global_avg_pooling")(x)
    # x = layers.Flatten()(x) # Alternative

    # Dense classification head
    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001), name="dense_1")(x)
    x = layers.Dropout(dense_dropout_rate, name="dense_dropout_1")(x)
    # x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001), name="dense_2")(x)        ## Worked well after removing this dense layer
    # x = layers.Dropout(dense_dropout_rate, name="dense_dropout_2")(x)     ## Worked well after commenting out this layer

    outputs = layers.Dense(num_classes_binary, activation='sigmoid', name="output_layer")(x)

    model = keras.Model(inputs, outputs, name="Extended_CNN1D_AMR_Model")
    return model

# MAX_SEQ_LEN, VOCAB_SIZE, EMBEDDING_DIM, CONV_DROPOUT_RATE, DROPOUT_RATE are defined in Cell 1
cnn_model = build_cnn1d_model_extended(MAX_SEQ_LEN, VOCAB_SIZE, EMBEDDING_DIM, 1, CONV_DROPOUT_RATE, DROPOUT_RATE)

cnn_model.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=LEARNING_RATE), # Or Adam
    loss='binary_crossentropy',
    metrics=['accuracy', keras.metrics.AUC(name='auc'), keras.metrics.Precision(name='precision'), keras.metrics.Recall(name='recall')]
)

cnn_model.summary()
# Out:
# --- Defining the 1D CNN Model (Extended to 6 Convolutional Blocks) ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "Extended_CNN1D_AMR_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ snp_input_sequence (InputLayer) │ (None, 60936)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_layer (Embedding)     │ (None, 60936, 64)      │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 60936, 128)     │        57,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_1                     │ (None, 60936, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_1 (Activation)             │ (None, 60936, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_1 (MaxPooling1D)        │ (None, 30468, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30468, 128)     │       114,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_2                     │ (None, 30468, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_2 (Activation)             │ (None, 30468, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_2 (MaxPooling1D)        │ (None, 15234, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 15234, 64)      │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_3                     │ (None, 15234, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_3 (Activation)             │ (None, 15234, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_3 (MaxPooling1D)        │ (None, 7617, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 7617, 64)       │        20,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_4                     │ (None, 7617, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_4 (Activation)             │ (None, 7617, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_4 (MaxPooling1D)        │ (None, 3808, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 3808, 32)       │         6,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_5                     │ (None, 3808, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_5 (Activation)             │ (None, 3808, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dropout_5 (Dropout)        │ (None, 3808, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 3808, 32)       │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_6                     │ (None, 3808, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_6 (Activation)             │ (None, 3808, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dropout_6 (Dropout)        │ (None, 3808, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling              │ (None, 32)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_dropout_1 (Dropout)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 249,601 (975.00 KB)
#  Trainable params: 248,705 (971.50 KB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# # **Model Training**

# %%
print("\n--- Starting 1D CNN Model Training ---")

# Calculating class weights for imbalanced dataset
neg_total, pos_total = np.bincount(labels) # Use original full 'labels' array
total_samples = neg_total + pos_total
weight_for_0_cnn = (1 / neg_total) * (total_samples / 2.0) if neg_total > 0 else 0
weight_for_1_cnn = (1 / pos_total) * (total_samples / 2.0) if pos_total > 0 else 0
class_weight_cnn = {0: weight_for_0_cnn, 1: weight_for_1_cnn}

print(f"Class weights for CNN: {class_weight_cnn}")

callbacks_list_cnn = [
    keras.callbacks.ModelCheckpoint(
        filepath="best_cnn1d_model_CTZ.keras",
        save_best_only=True,
        monitor="val_auc", # Monitoring validation AUC for best model
        mode="max"
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=40,         # Stop if val_auc doesn't improve for 60 epochs (a bit too much but it works!)
        mode="max",
        restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=4,
        min_lr=5e-6        # Can be tuned
    )
]

history_cnn = cnn_model.fit(
    X_train, y_train, # X_train should be integer encoded
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_test, y_test), # X_val should be integer encoded
    callbacks=callbacks_list_cnn,
    class_weight=class_weight_cnn
)

print("--- 1D CNN Training Finished ---")

# Plotting training history
history_df_cnn = pd.DataFrame(history_cnn.history)
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
history_df_cnn[['loss', 'val_loss']].plot(ax=axes[0])
axes[0].set_title('1D CNN Loss Curve')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
history_df_cnn[['accuracy', 'val_accuracy', 'auc', 'val_auc']].plot(ax=axes[1])
axes[1].set_title('1D CNN Accuracy & AUC Curve')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Metric Value')
plt.tight_layout()
plt.show()
# Out:
# --- Starting 1D CNN Model Training ---
# Class weights for CNN: {0: np.float64(0.7589118198874296), 1: np.float64(1.4655797101449275)}
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.5101 - auc: 0.5378 - loss: 1.5970 - precision: 0.3575 - recall: 0.5245 - val_accuracy: 0.6605 - val_auc: 0.5455 - val_loss: 1.1765 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.5697 - auc: 0.6321 - loss: 1.2840 - precision: 0.4082 - recall: 0.5807 - val_accuracy: 0.6605 - val_auc: 0.5640 - val_loss: 1.1754 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 350ms/step - accuracy: 0.6193 - auc: 0.6232 - loss: 1.2459 - precision: 0.4543 - recall: 0.4781 - val_accuracy: 0.6605 - val_auc: 0.5262 - val_loss: 1.1685 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s
150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8231 - auc: 0.8808 - loss: 0.8841 - precision: 0.7085 - recall: 0.8290 - val_accuracy: 0.3889 - val_auc: 0.4943 - val_loss: 1.1773 - val_precision: 0.3553 - val_recall: 0.9818 - learning_rate: 2.0000e-04
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8475 - auc: 0.8964 - loss: 0.8541 - precision: 0.7514 - recall: 0.8309 - val_accuracy: 0.3580 - val_auc: 0.5022 - val_loss: 1.1800 - val_precision: 0.3439 - val_recall: 0.9818 - learning_rate: 2.0000e-04
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8399 - auc: 0.8946 - loss: 0.8516 - precision: 0.7251 - recall: 0.8568 - val_accuracy: 0.3519 - val_auc: 0.5635 - val_loss: 1.1791 - val_precision: 0.3418 - val_recall: 0.9818 - learning_rate: 2.0000e-04
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 371ms/step - accuracy: 0.8349 - auc: 0.9180 - loss: 0.8106 - precision: 0.7176 - recall: 0.8575 - val_accuracy: 0.3580 - val_auc: 0.6563 - val_loss: 1.1709 - val_precision: 0.3439 - val_recall: 0.9818 - learning_rate: 2.0000e-04
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.8488 - auc: 0.9229 - loss: 0.7965 - precision: 0.7304 - recall: 0.8848 - val_accuracy: 0.3704 - val_auc: 0.7030 - val_loss: 1.1659 - val_precision: 0.3484 - val_recall: 0.9818 - learning_rate: 4.0000e-05
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8652 - auc: 0.9215 - loss: 0.8033 - precision: 0.7729 - recall: 0.8618 - val_accuracy: 0.4630 - val_auc: 0.7307 - val_loss: 1.1527 - val_precision: 0.3841 - val_recall: 0.9636 - learning_rate: 4.0000e-05
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8571 - auc: 0.9173 - loss: 0.8026 - precision: 0.7508 - recall: 0.8731 - val_accuracy: 0.5309 - val_auc: 0.7624 - val_loss: 1.1282 - val_precision: 0.4160 - val_recall: 0.9455 - learning_rate: 4.0000e-05
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8703 - auc: 0.9238 - loss: 0.7949 - precision: 0.7782 - recall: 0.8701 - val_accuracy: 0.5741 - val_auc: 0.7828 - val_loss: 1.0962 - val_precision: 0.4386 - val_recall: 0.9091 - learning_rate: 4.0000e-05
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8517 - auc: 0.9222 - loss: 0.8003 - precision: 0.7442 - recall: 0.8662 - val_accuracy: 0.6111 - val_auc: 0.7897 - val_loss: 1.0659 - val_precision: 0.4583 - val_recall: 0.8000 - learning_rate: 4.0000e-05
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8523 - auc: 0.9224 - loss: 0.7998 - precision: 0.7413 - recall: 0.8743 - val_accuracy: 0.6543 - val_auc: 0.7996 - val_loss: 1.0347 - val_precision: 0.4943 - val_recall: 0.7818 - learning_rate: 4.0000e-05
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8629 - auc: 0.9260 - loss: 0.7894 - precision: 0.7502 - recall: 0.9011 - val_accuracy: 0.7099 - val_auc: 0.8027 - val_loss: 1.0036 - val_precision: 0.5541 - val_recall: 0.7455 - learning_rate: 4.0000e-05
# Epoch 30/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8516 - auc: 0.9217 - loss: 0.7954 - precision: 0.7378 - recall: 0.8830 - val_accuracy: 0.7222 - val_auc: 0.8050 - val_loss: 0.9843 - val_precision: 0.5714 - val_recall: 0.7273 - learning_rate: 4.0000e-05
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8711 - auc: 0.9245 - loss: 0.7882 - precision: 0.7669 - recall: 0.8983 - val_accuracy: 0.7284 - val_auc: 0.8055 - val_loss: 0.9794 - val_precision: 0.5797 - val_recall: 0.7273 - learning_rate: 4.0000e-05
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8531 - auc: 0.9176 - loss: 0.8024 - precision: 0.7367 - recall: 0.8886 - val_accuracy: 0.7407 - val_auc: 0.8060 - val_loss: 0.9669 - val_precision: 0.5970 - val_recall: 0.7273 - learning_rate: 4.0000e-05
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8585 - auc: 0.9278 - loss: 0.7784 - precision: 0.7538 - recall: 0.8710 - val_accuracy: 0.7531 - val_auc: 0.8073 - val_loss: 0.9605 - val_precision: 0.6154 - val_recall: 0.7273 - learning_rate: 4.0000e-05
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8605 - auc: 0.9387 - loss: 0.7633 - precision: 0.7551 - recall: 0.8791 - val_accuracy: 0.7593 - val_auc: 0.8071 - val_loss: 0.9594 - val_precision: 0.6290 - val_recall: 0.7091 - learning_rate: 4.0000e-05
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8835 - auc: 0.9314 - loss: 0.7681 - precision: 0.7860 - recall: 0.9096 - val_accuracy: 0.7593 - val_auc: 0.8095 - val_loss: 0.9601 - val_precision: 0.6290 - val_recall: 0.7091 - learning_rate: 4.0000e-05
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8596 - auc: 0.9380 - loss: 0.7640 - precision: 0.7543 - recall: 0.8734 - val_accuracy: 0.7654 - val_auc: 0.8110 - val_loss: 0.9613 - val_precision: 0.6393 - val_recall: 0.7091 - learning_rate: 4.0000e-05
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8567 - auc: 0.9288 - loss: 0.7809 - precision: 0.7597 - recall: 0.8543 - val_accuracy: 0.7654 - val_auc: 0.8059 - val_loss: 0.9652 - val_precision: 0.6393 - val_recall: 0.7091 - learning_rate: 4.0000e-05
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8633 - auc: 0.9315 - loss: 0.7746 - precision: 0.7497 - recall: 0.9057 - val_accuracy: 0.7654 - val_auc: 0.8027 - val_loss: 0.9681 - val_precision: 0.6441 - val_recall: 0.6909 - learning_rate: 4.0000e-05
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8676 - auc: 0.9361 - loss: 0.7613 - precision: 0.7640 - recall: 0.8873 - val_accuracy: 0.7654 - val_auc: 0.8025 - val_loss: 0.9695 - val_precision: 0.6441 - val_recall: 0.6909 - learning_rate: 8.0000e-06
# Epoch 40/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8637 - auc: 0.9403 - loss: 0.7497 - precision: 0.7481 - recall: 0.9068 - val_accuracy: 0.7716 - val_auc: 0.8010 - val_loss: 0.9708 - val_precision: 0.6500 - val_recall: 0.7091 - learning_rate: 8.0000e-06
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8769 - auc: 0.9417 - loss: 0.7433 - precision: 0.7811 - recall: 0.8910 - val_accuracy: 0.7716 - val_auc: 0.8014 - val_loss: 0.9721 - val_precision: 0.6552 - val_recall: 0.6909 - learning_rate: 8.0000e-06
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8726 - auc: 0.9324 - loss: 0.7761 - precision: 0.7666 - recall: 0.9044 - val_accuracy: 0.7778 - val_auc: 0.8022 - val_loss: 0.9740 - val_precision: 0.6610 - val_recall: 0.7091 - learning_rate: 8.0000e-06
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8720 - auc: 0.9400 - loss: 0.7600 - precision: 0.7675 - recall: 0.9022 - val_accuracy: 0.7778 - val_auc: 0.8027 - val_loss: 0.9745 - val_precision: 0.6610 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8722 - auc: 0.9360 - loss: 0.7632 - precision: 0.7647 - recall: 0.9078 - val_accuracy: 0.7778 - val_auc: 0.8032 - val_loss: 0.9751 - val_precision: 0.6610 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8690 - auc: 0.9394 - loss: 0.7567 - precision: 0.7676 - recall: 0.8845 - val_accuracy: 0.7778 - val_auc: 0.8027 - val_loss: 0.9757 - val_precision: 0.6610 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8730 - auc: 0.9365 - loss: 0.7552 - precision: 0.7613 - recall: 0.9191 - val_accuracy: 0.7778 - val_auc: 0.8021 - val_loss: 0.9764 - val_precision: 0.6610 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 357ms/step - accuracy: 0.8750 - auc: 0.9428 - loss: 0.7493 - precision: 0.7685 - recall: 0.9079 - val_accuracy: 0.7840 - val_auc: 0.8033 - val_loss: 0.9770 - val_precision: 0.6724 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8727 - auc: 0.9385 - loss: 0.7596 - precision: 0.7779 - recall: 0.8799 - val_accuracy: 0.7840 - val_auc: 0.8021 - val_loss: 0.9778 - val_precision: 0.6724 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8761 - auc: 0.9330 - loss: 0.7644 - precision: 0.7746 - recall: 0.9016 - val_accuracy: 0.7840 - val_auc: 0.8017 - val_loss: 0.9781 - val_precision: 0.6724 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 50/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.8636 - auc: 0.9360 - loss: 0.7658 - precision: 0.7622 - recall: 0.8722 - val_accuracy: 0.7840 - val_auc: 0.8027 - val_loss: 0.9788 - val_precision: 0.6724 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 51/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8801 - auc: 0.9382 - loss: 0.7573 - precision: 0.7766 - recall: 0.9148 - val_accuracy: 0.7840 - val_auc: 0.8013 - val_loss: 0.9790 - val_precision: 0.6724 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 52/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8895 - auc: 0.9363 - loss: 0.7544 - precision: 0.7882 - recall: 0.9285 - val_accuracy: 0.7840 - val_auc: 0.8015 - val_loss: 0.9794 - val_precision: 0.6724 - val_recall: 0.7091 - learning_rate: 5.0000e-06
# Epoch 53/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.
- val_precision: 0.6667 - val_recall: 0.6909 - learning_rate: 5.0000e-06
# Epoch 86/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8658 - auc: 0.9403 - loss: 0.7503 - precision: 0.7521 - recall: 0.9088 - val_accuracy: 0.7778 - val_auc: 0.8019 - val_loss: 0.9811 - val_precision: 0.6667 - val_recall: 0.6909 - learning_rate: 5.0000e-06
# Epoch 87/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.8812 - auc: 0.9383 - loss: 0.7503 - precision: 0.7804 - recall: 0.9093 - val_accuracy: 0.7778 - val_auc: 0.8033 - val_loss: 0.9805 - val_precision: 0.6667 - val_recall: 0.6909 - learning_rate: 5.0000e-06
# --- 1D CNN Training Finished ---

# %% [markdown]
# # **Model Evaluation**

# %%
print("\n--- Evaluating 1D CNN Model on Test Set ---")

# Load the best CNN model saved by the callback
best_cnn_model = keras.models.load_model("best_cnn1d_model_CTZ.keras")

# --- Predictions on the Test Set ---
# Getting probabilities for AUC and ROC curve
y_pred_probs_cnn = best_cnn_model.predict(X_test, verbose=0).ravel()
# Getting class predictions (using 0.62 threshold) for other metrics
y_pred_classes_cnn = (y_pred_probs_cnn > 0.62).astype(int)

# --- Calculating All Metrics ---
accuracy_cnn = accuracy_score(y_test, y_pred_classes_cnn)
auc_cnn = roc_auc_score(y_test, y_pred_probs_cnn)
kappa_cnn = cohen_kappa_score(y_test, y_pred_classes_cnn)
mcc_cnn = matthews_corrcoef(y_test, y_pred_classes_cnn)

print(f"\nOverall Performance Metrics (Test Set):")
print(f"Accuracy: {accuracy_cnn:.4f}")
print(f"AUC Score: {auc_cnn:.4f}")
print(f"Cohen's Kappa: {kappa_cnn:.4f}")
print(f"Matthews Correlation Coefficient (MCC): {mcc_cnn:.4f}")

# --- Classification Report ---
print("\nClassification Report:")
report_cnn = classification_report(
    y_test,
    y_pred_classes_cnn,
    target_names=["Susceptible (0)", "Resistant (1)"],
    digits=4
)
print(report_cnn)

# --- Confusion Matrix ---
print("\nConfusion Matrix:")
cm_cnn = confusion_matrix(y_test, y_pred_classes_cnn)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_cnn, annot=True, fmt='d', cmap='Greens',
            xticklabels=["Susceptible", "Resistant"],
            yticklabels=["Susceptible", "Resistant"])
plt.ylabel('Actual')
plt.xlabel('Predicted')
#plt.title(f'Confusion Matrix - {TARGET_ANTIBIOTIC} (1D CNN)')
plt.show()

# --- ROC Curve ---
fpr_cnn, tpr_cnn, _ = roc_curve(y_test, y_pred_probs_cnn)
plt.figure(figsize=(7, 6))
plt.plot(fpr_cnn, tpr_cnn, color='green', lw=2, label=f'ROC curve (AUC = {auc_cnn:.4f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title(f'ROC Curve - {TARGET_ANTIBIOTIC} (1D CNN)')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()
# Out:
# --- Evaluating 1D CNN Model on Test Set ---
#
# Overall Performance Metrics (Test Set):
# Accuracy: 0.8086
# AUC Score: 0.8104
# Cohen's Kappa: 0.5637
# Matthews Correlation Coefficient (MCC): 0.5651
#
# Classification Report:
#                  precision    recall  f1-score   support
#
# Susceptible (0)     0.8393    0.8785    0.8584       107
#   Resistant (1)     0.7400    0.6727    0.7048        55
#
#        accuracy                         0.8086       162
#       macro avg     0.7896    0.7756    0.7816       162
#    weighted avg     0.8056    0.8086    0.8063       162
#
#
# Confusion Matrix:

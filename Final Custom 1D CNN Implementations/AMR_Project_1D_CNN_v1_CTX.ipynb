# %% [markdown]
# # **AntiMicrobial Resistance Prediction from SNPs**

# %% [markdown]
# This notebook contains the end-to-end Custom 1D CNN implementation of **AMR Prediction from SNPs** project for the Cefotaxime (CTX) antibiotic. Feel free to use/customise the model architecture.

# %% [markdown]
# #**Setup & Imports**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, regularizers, Model
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix, roc_curve, accuracy_score, cohen_kappa_score, matthews_corrcoef
import seaborn as sns

# --- Configuration ---
SNP_MATRIX_FILE = "/content/drive/MyDrive/AMR/Giessen_dataset/cip_ctx_ctz_gen_multi_data.csv"
PHENOTYPES_FILE = "/content/drive/MyDrive/AMR/Giessen_dataset/cip_ctx_ctz_gen_pheno.csv"
TARGET_ANTIBIOTIC = "CTX"
# Model Hyperparameters for 1D CNN
VOCAB_SIZE = 5      # N:0, A:1, G:2, C:3, T:4
EMBEDDING_DIM = 64  # Dimension for the embedding layer (can be tuned)
MAX_SEQ_LEN = None  # Will be determined from data
DROPOUT_RATE = 0.45  # Regularization for Dense layers
CONV_DROPOUT_RATE = 0.15 # Regularization for Conv layers

# Training Hyperparameters
EPOCHS = 150 # Can be tuned
BATCH_SIZE = 32 # Can be tuned
LEARNING_RATE = 1e-3 # Can be tuned
VALIDATION_SPLIT = 0.15
TEST_SPLIT = 0.2

# Seed for reproducibility (Can be shuffled)
tf.random.set_seed(42)
np.random.seed(42)

# Checking for GPU
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"Using GPU: {gpus[0].name}")
    except RuntimeError as e:
        print(e)
else:
    print("Using CPU")
# Out:
# Using GPU: /physical_device:GPU:0

# %% [markdown]
# # **Initial Preprocessing**

# %%
print("\n--- Loading and Preprocessing Data for 1D CNN ---")
try:
    snp_df_raw = pd.read_csv(SNP_MATRIX_FILE)
    pheno_df = pd.read_csv(PHENOTYPES_FILE)
except FileNotFoundError:
    print(f"ERROR: Ensure '{SNP_MATRIX_FILE}' and '{PHENOTYPES_FILE}' are in the same directory.")
    exit()

print(f"Raw SNP matrix shape: {snp_df_raw.shape}")
print(f"Phenotypes shape: {pheno_df.shape}")

# Setting 'prename' as index for easy merging
snp_df = snp_df_raw.set_index('prename')
pheno_df = pheno_df.set_index('prename')

# Merging SNP data with phenotype data
merged_df = snp_df.join(pheno_df[TARGET_ANTIBIOTIC], how='inner')
print(f"Merged data shape: {merged_df.shape}")

# Handling potential NaN values
merged_df = merged_df.dropna(subset=[TARGET_ANTIBIOTIC])
# Filling NaNs in SNP features with 0 (assuming this corresponds to 'N' or unknown)
merged_df = merged_df.fillna(0)
print(f"Shape after dropping NaNs in target and filling NaNs in features: {merged_df.shape}")

# Separating features (SNPs) and labels
labels = merged_df[TARGET_ANTIBIOTIC].values.astype(np.int32)
features_df = merged_df.drop(columns=[TARGET_ANTIBIOTIC])

snp_position_names = features_df.columns.tolist()

# --- Integer Encoding (Data is already in this format 0-4) ---
X_integer_encoded = features_df.values.astype(np.int32)

MAX_SEQ_LEN = X_integer_encoded.shape[1] # This is the number of SNP positions
print(f"Sequence length (number of SNPs): {MAX_SEQ_LEN}")
print(f"Labels shape: {labels.shape}")
print(f"Class distribution: Resistant (1): {np.sum(labels == 1)}, Susceptible (0): {np.sum(labels == 0)}")
if np.any(X_integer_encoded >= VOCAB_SIZE) or np.any(X_integer_encoded < 0):
    print("WARNING: SNP values out of expected range [0, VOCAB_SIZE-1]. Check encoding.")
# Out:
# --- Loading and Preprocessing Data for 1D CNN ---
# Raw SNP matrix shape: (809, 60937)
# Phenotypes shape: (809, 5)
# Merged data shape: (809, 60937)
# Shape after dropping NaNs in target and filling NaNs in features: (809, 60937)
# Sequence length (number of SNPs): 60936
# Labels shape: (809,)
# Class distribution: Resistant (1): 358, Susceptible (0): 451

# %% [markdown]
# # **Data Splitting**

# %%
print("\n--- Splitting Data ---")

X_train, X_test, y_train, y_test = train_test_split(
    X_integer_encoded, labels,
    test_size=TEST_SPLIT,
    random_state=42,
    stratify=labels
)

print(f"Training samples: {X_train.shape[0]}, Sequence Length: {X_train.shape[1]}")
print(f"Test samples: {X_test.shape[0]}")
# Out:
# --- Splitting Data ---
# Training samples: 647, Sequence Length: 60936
# Test samples: 162

# %% [markdown]
# # **1D CNN Model Definition**

# %%
print("\n--- Defining the 1D CNN Model (Extended to 6 Convolutional Blocks) ---")

def build_cnn1d_model_extended(maxlen, vocab_size, embed_dim, num_classes_binary, conv_dropout_rate, dense_dropout_rate):
    inputs = keras.Input(shape=(maxlen,), name="snp_input_sequence")

    # Embedding layer
    x = layers.Embedding(input_dim=vocab_size,
                         output_dim=embed_dim,
                         input_length=maxlen,
                         name="embedding_layer")(inputs)
    # x = layers.SpatialDropout1D(0.15)(x) # Optional: Dropout after embedding, slightly increased (I don't recommend it!)

    # Convolutional blocks - Doubled
    # Block 1
    x = layers.Conv1D(filters=128, kernel_size=7, padding="same",
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_1")(x)
    x = layers.BatchNormalization(name="batchnorm_1")(x)
    x = layers.Activation("relu", name="relu_1")(x)
    x = layers.MaxPooling1D(pool_size=2, name="maxpool_1")(x) # Adjusted pool_size slightly
    # x = layers.Dropout(conv_dropout_rate, name="conv_dropout_1")(x)    ## Worked well after commenting out this layer

    # Block 2
    x = layers.Conv1D(filters=128, kernel_size=7, padding="same", # Repeating similar block
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_2")(x)
    x = layers.BatchNormalization(name="batchnorm_2")(x)
    x = layers.Activation("relu", name="relu_2")(x)
    x = layers.MaxPooling1D(pool_size=2, name="maxpool_2")(x) # Adjusted pool_size
    # x = layers.Dropout(conv_dropout_rate, name="conv_dropout_2")(x)    ## Worked well after commenting out this layer

    # Block 3
    x = layers.Conv1D(filters=64, kernel_size=5, padding="same",
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_3")(x)
    x = layers.BatchNormalization(name="batchnorm_3")(x)
    x = layers.Activation("relu", name="relu_3")(x)
    x = layers.MaxPooling1D(pool_size=2, name="maxpool_3")(x) # Adjusted pool_size
    # x = layers.Dropout(conv_dropout_rate, name="conv_dropout_3")(x)    ## Worked well after commenting out this layer

    # Block 4
    x = layers.Conv1D(filters=64, kernel_size=5, padding="same", # Repeating similar block
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_4")(x)
    x = layers.BatchNormalization(name="batchnorm_4")(x)
    x = layers.Activation("relu", name="relu_4")(x)
    x = layers.MaxPooling1D(pool_size=2, name="maxpool_4")(x) # Adjusted pool_size
    # x = layers.Dropout(conv_dropout_rate, name="conv_dropout_4")(x)    ## Worked well after commenting out this layer

    # Block 5
    x = layers.Conv1D(filters=32, kernel_size=3, padding="same",
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_5")(x)
    x = layers.BatchNormalization(name="batchnorm_5")(x)
    x = layers.Activation("relu", name="relu_5")(x)
    # No MaxPooling after the last few conv blocks sometimes helps retain info before GlobalPooling
    x = layers.Dropout(conv_dropout_rate, name="conv_dropout_5")(x)


    # Block 6
    x = layers.Conv1D(filters=32, kernel_size=3, padding="same",
                      kernel_regularizer=regularizers.l2(0.001), name="conv1d_6")(x)
    x = layers.BatchNormalization(name="batchnorm_6")(x)
    x = layers.Activation("relu", name="relu_6")(x)
    # No MaxPooling here either
    x = layers.Dropout(conv_dropout_rate, name="conv_dropout_6")(x)


    # Flatten or Pool for Dense layers
    x = layers.GlobalMaxPooling1D(name="global_max_pooling")(x)         ## GlobalMaxPooling worked better than flattening and GlobalAvgPooling
    # x = layers.GlobalAveragePooling1D(name="global_avg_pooling")(x)
    # x = layers.Flatten()(x) # Alternative

    # Dense classification head
    x = layers.Dense(128, activation='relu', kernel_regularizer=regularizers.l2(0.001), name="dense_1")(x)
    x = layers.Dropout(dense_dropout_rate, name="dense_dropout_1")(x)
    # x = layers.Dense(64, activation='relu', kernel_regularizer=regularizers.l2(0.001), name="dense_2")(x)        ## Worked well after removing this dense layer
    # x = layers.Dropout(dense_dropout_rate, name="dense_dropout_2")(x)     ## Worked well after commenting out this layer

    outputs = layers.Dense(num_classes_binary, activation='sigmoid', name="output_layer")(x)

    model = keras.Model(inputs, outputs, name="Extended_CNN1D_AMR_Model")
    return model

# MAX_SEQ_LEN, VOCAB_SIZE, EMBEDDING_DIM, CONV_DROPOUT_RATE, DROPOUT_RATE are defined in Cell 1
cnn_model = build_cnn1d_model_extended(MAX_SEQ_LEN, VOCAB_SIZE, EMBEDDING_DIM, 1, CONV_DROPOUT_RATE, DROPOUT_RATE)

cnn_model.compile(
    optimizer=keras.optimizers.AdamW(learning_rate=LEARNING_RATE), # Or Adam
    loss='binary_crossentropy',
    metrics=['accuracy', keras.metrics.AUC(name='auc'), keras.metrics.Precision(name='precision'), keras.metrics.Recall(name='recall')]
)

cnn_model.summary()
# Out:
# --- Defining the 1D CNN Model (Extended to 6 Convolutional Blocks) ---
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "Extended_CNN1D_AMR_Model"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ snp_input_sequence (InputLayer) │ (None, 60936)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ embedding_layer (Embedding)     │ (None, 60936, 64)      │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 60936, 128)     │        57,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_1                     │ (None, 60936, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_1 (Activation)             │ (None, 60936, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_1 (MaxPooling1D)        │ (None, 30468, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 30468, 128)     │       114,816 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_2                     │ (None, 30468, 128)     │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_2 (Activation)             │ (None, 30468, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_2 (MaxPooling1D)        │ (None, 15234, 128)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 15234, 64)      │        41,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_3                     │ (None, 15234, 64)      │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_3 (Activation)             │ (None, 15234, 64)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_3 (MaxPooling1D)        │ (None, 7617, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_4 (Conv1D)               │ (None, 7617, 64)       │        20,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_4                     │ (None, 7617, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_4 (Activation)             │ (None, 7617, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ maxpool_4 (MaxPooling1D)        │ (None, 3808, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 3808, 32)       │         6,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_5                     │ (None, 3808, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_5 (Activation)             │ (None, 3808, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dropout_5 (Dropout)        │ (None, 3808, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, 3808, 32)       │         3,104 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batchnorm_6                     │ (None, 3808, 32)       │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ relu_6 (Activation)             │ (None, 3808, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dropout_6 (Dropout)        │ (None, 3808, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_max_pooling              │ (None, 32)             │             0 │
# │ (GlobalMaxPooling1D)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_dropout_1 (Dropout)       │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output_layer (Dense)            │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 249,601 (975.00 KB)
#  Trainable params: 248,705 (971.50 KB)
#  Non-trainable params: 896 (3.50 KB)

# %% [markdown]
# # **Model Training**

# %%
print("\n--- Starting 1D CNN Model Training ---")

# Calculating class weights for imbalanced dataset
neg_total, pos_total = np.bincount(labels)
total_samples = neg_total + pos_total
weight_for_0_cnn = (1 / neg_total) * (total_samples / 2.0) if neg_total > 0 else 0
weight_for_1_cnn = (1 / pos_total) * (total_samples / 2.0) if pos_total > 0 else 0
class_weight_cnn = {0: weight_for_0_cnn, 1: weight_for_1_cnn}

print(f"Class weights for CNN: {class_weight_cnn}")

callbacks_list_cnn = [
    keras.callbacks.ModelCheckpoint(
        filepath="best_cnn1d_model_CTZ.keras",
        save_best_only=True,
        monitor="val_auc", # Monitoring validation AUC for best model
        mode="max"
    ),
    keras.callbacks.EarlyStopping(
        monitor="val_accuracy",
        patience=40,         # Stop if val_auc doesn't improve for 60 epochs (a bit too much but it works!)
        mode="max",
        restore_best_weights=True
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.2,
        patience=4,
        min_lr=5e-6        # Can be tuned
    )
]

history_cnn = cnn_model.fit(
    X_train, y_train, # X_train should be integer encoded
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_test, y_test), # X_val should be integer encoded
    callbacks=callbacks_list_cnn,
    class_weight=class_weight_cnn
)

print("--- 1D CNN Training Finished ---")

# Plotting training history
history_df_cnn = pd.DataFrame(history_cnn.history)
fig, axes = plt.subplots(1, 2, figsize=(15, 5))
history_df_cnn[['loss', 'val_loss']].plot(ax=axes[0])
axes[0].set_title('1D CNN Loss Curve')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
history_df_cnn[['accuracy', 'val_accuracy', 'auc', 'val_auc']].plot(ax=axes[1])
axes[1].set_title('1D CNN Accuracy & AUC Curve')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Metric Value')
plt.tight_layout()
plt.show()
# Out:
# --- Starting 1D CNN Model Training ---
# Class weights for CNN: {0: np.float64(0.8968957871396895), 1: np.float64(1.1298882681564246)}
# Epoch 1/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.5142 - auc: 0.5339 - loss: 1.6961 - precision: 0.4614 - recall: 0.5811 - val_accuracy: 0.5556 - val_auc: 0.5028 - val_loss: 1.1799 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 354ms/step - accuracy: 0.5148 - auc: 0.5007 - loss: 1.4365 - precision: 0.4560 - recall: 0.4858 - val_accuracy: 0.4444 - val_auc: 0.4215 - val_loss: 1.1815 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 3/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.6244 - auc: 0.6502 - loss: 1.1924 - precision: 0.5729 - recall: 0.5947 - val_accuracy: 0.4444 - val_auc: 0.5332 - val_loss: 1.1797 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 4/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 355ms/step - accuracy: 0.6301 - auc: 0.6665 - loss: 1.1840 - precision: 0.5748 - recall: 0.6414 - val_accuracy: 0.4444 - val_auc: 0.4829 - val_loss: 1.1757 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 5/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.6428 - auc: 0.7126 - loss: 1.1087 - precision: 0.5886 - recall: 0.6221 - val_accuracy: 0.4444 - val_auc: 0.5352 - val_loss: 1.1911 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 6/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 7s 356ms/step - accuracy: 0.6595 - auc: 0.7301 - loss: 1.0941 - precision: 0.6055 - recall: 0.6675 - val_accuracy: 0.4444 - val_auc: 0.5326 - val_loss: 1.1998 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 7/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 363ms/step - accuracy: 0.6951 - auc: 0.7724 - loss: 1.0536 - precision: 0.6487 - recall: 0.6823 - val_accuracy: 0.4444 - val_auc: 0.5443 - val_loss: 1.1942 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 8/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 358ms/step - accuracy: 0.6992 - auc: 0.7757 - loss: 1.0390 - precision: 0.6446 - recall: 0.7164 - val_accuracy: 0.4444 - val_auc: 0.5380 - val_loss: 1.1879 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 0.0010
# Epoch 9/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.7372 - auc: 0.8019 - loss: 1.0109 - precision: 0.6825 - recall: 0.7585 - val_accuracy: 0.4444 - val_auc: 0.5149 - val_loss: 1.1892 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 10/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7487 - auc: 0.8167 - loss: 0.9911 - precision: 0.6972 - recall: 0.7666 - val_accuracy: 0.4444 - val_auc: 0.5592 - val_loss: 1.1846 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 11/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7238 - auc: 0.7970 - loss: 1.0258 - precision: 0.6723 - recall: 0.7332 - val_accuracy: 0.4444 - val_auc: 0.6389 - val_loss: 1.1803 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 12/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - accuracy: 0.7412 - auc: 0.8213 - loss: 0.9862 - precision: 0.6935 - recall: 0.7443 - val_accuracy: 0.4444 - val_auc: 0.6401 - val_loss: 1.1802 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 2.0000e-04
# Epoch 13/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.7643 - auc: 0.8427 - loss: 0.9527 - precision: 0.7143 - recall: 0.7786 - val_accuracy: 0.4444 - val_auc: 0.6291 - val_loss: 1.1774 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 14/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - accuracy: 0.7572 - auc: 0.8302 - loss: 0.9736 - precision: 0.7081 - recall: 0.7677 - val_accuracy: 0.4444 - val_auc: 0.6487 - val_loss: 1.1738 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 15/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7598 - auc: 0.8346 - loss: 0.9721 - precision: 0.7049 - recall: 0.7864 - val_accuracy: 0.4444 - val_auc: 0.6657 - val_loss: 1.1698 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 16/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - accuracy: 0.7873 - auc: 0.8489 - loss: 0.9424 - precision: 0.7493 - recall: 0.7800 - val_accuracy: 0.4444 - val_auc: 0.6889 - val_loss: 1.1641 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 17/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7726 - auc: 0.8377 - loss: 0.9653 - precision: 0.7243 - recall: 0.7850 - val_accuracy: 0.4444 - val_auc: 0.7121 - val_loss: 1.1577 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 18/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 366ms/step - accuracy: 0.7599 - auc: 0.8415 - loss: 0.9524 - precision: 0.7153 - recall: 0.7608 - val_accuracy: 0.4444 - val_auc: 0.7234 - val_loss: 1.1528 - val_precision: 0.4444 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 19/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 366ms/step - accuracy: 0.7695 - auc: 0.8448 - loss: 0.9526 - precision: 0.7366 - recall: 0.7445 - val_accuracy: 0.4691 - val_auc: 0.7437 - val_loss: 1.1466 - val_precision: 0.4557 - val_recall: 1.0000 - learning_rate: 4.0000e-05
# Epoch 20/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 366ms/step - accuracy: 0.8000 - auc: 0.8498 - loss: 0.9429 - precision: 0.7578 - recall: 0.8049 - val_accuracy: 0.5247 - val_auc: 0.7533 - val_loss: 1.1385 - val_precision: 0.4828 - val_recall: 0.9722 - learning_rate: 4.0000e-05
# Epoch 21/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7687 - auc: 0.8503 - loss: 0.9415 - precision: 0.7219 - recall: 0.7763 - val_accuracy: 0.6420 - val_auc: 0.7629 - val_loss: 1.1290 - val_precision: 0.5593 - val_recall: 0.9167 - learning_rate: 4.0000e-05
# Epoch 22/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 369ms/step - accuracy: 0.7845 - auc: 0.8572 - loss: 0.9353 - precision: 0.7447 - recall: 0.7776 - val_accuracy: 0.7037 - val_auc: 0.7749 - val_loss: 1.1166 - val_precision: 0.6176 - val_recall: 0.8750 - learning_rate: 4.0000e-05
# Epoch 23/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - accuracy: 0.7864 - auc: 0.8508 - loss: 0.9404 - precision: 0.7286 - recall: 0.8232 - val_accuracy: 0.7222 - val_auc: 0.8125 - val_loss: 1.0992 - val_precision: 0.6421 - val_recall: 0.8472 - learning_rate: 4.0000e-05
# Epoch 24/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - accuracy: 0.7650 - auc: 0.8531 - loss: 0.9373 - precision: 0.7315 - recall: 0.7406 - val_accuracy: 0.7469 - val_auc: 0.8248 - val_loss: 1.0819 - val_precision: 0.6703 - val_recall: 0.8472 - learning_rate: 4.0000e-05
# Epoch 25/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - accuracy: 0.7774 - auc: 0.8565 - loss: 0.9315 - precision: 0.7327 - recall: 0.7826 - val_accuracy: 0.7531 - val_auc: 0.8278 - val_loss: 1.0569 - val_precision: 0.6702 - val_recall: 0.8750 - learning_rate: 4.0000e-05
# Epoch 26/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7797 - auc: 0.8633 - loss: 0.9193 - precision: 0.7342 - recall: 0.7864 - val_accuracy: 0.7654 - val_auc: 0.8302 - val_loss: 1.0332 - val_precision: 0.6977 - val_recall: 0.8333 - learning_rate: 4.0000e-05
# Epoch 27/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 368ms/step - accuracy: 0.7905 - auc: 0.8604 - loss: 0.9280 - precision: 0.7417 - recall: 0.8079 - val_accuracy: 0.7716 - val_auc: 0.8317 - val_loss: 1.0161 - val_precision: 0.7108 - val_recall: 0.8194 - learning_rate: 4.0000e-05
# Epoch 28/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8048 - auc: 0.8759 - loss: 0.9016 - precision: 0.7710 - recall: 0.7936 - val_accuracy: 0.7716 - val_auc: 0.8308 - val_loss: 0.9982 - val_precision: 0.7160 - val_recall: 0.8056 - learning_rate: 4.0000e-05
# Epoch 29/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7847 - auc: 0.8586 - loss: 0.9274 - precision: 0.7348 - recall: 0.8031 - val_accuracy: 0.7840 - val_auc: 0.8324 - val_loss: 0.9861 - val_precision: 0.7403 - val_recall: 0.7917 - learning_rate: 4.0000e-05
# Epoch 30/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 367ms/step - accuracy: 0.7961 - auc: 0.8748 - loss: 0.9046 - precision: 0.7379 - recall: 0.8366 - val_accuracy: 0.7840 - val_auc: 0.8375 - val_loss: 0.9739 - val_precision: 0.7467 - val_recall: 0.7778 - learning_rate: 4.0000e-05
# Epoch 31/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8005 - auc: 0.8619 - loss: 0.9178 - precision: 0.7640 - recall: 0.7947 - val_accuracy: 0.7840 - val_auc: 0.8351 - val_loss: 0.9678 - val_precision: 0.7467 - val_recall: 0.7778 - learning_rate: 4.0000e-05
# Epoch 32/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8290 - auc: 0.8644 - loss: 0.9189 - precision: 0.8044 - recall: 0.8101 - val_accuracy: 0.7716 - val_auc: 0.8278 - val_loss: 0.9670 - val_precision: 0.7215 - val_recall: 0.7917 - learning_rate: 4.0000e-05
# Epoch 33/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.8018 - auc: 0.8694 - loss: 0.9077 - precision: 0.7575 - recall: 0.8120 - val_accuracy: 0.7840 - val_auc: 0.8255 - val_loss: 0.9623 - val_precision: 0.7467 - val_recall: 0.7778 - learning_rate: 4.0000e-05
# Epoch 34/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8015 - auc: 0.8819 - loss: 0.8907 - precision: 0.7679 - recall: 0.7894 - val_accuracy: 0.7778 - val_auc: 0.8275 - val_loss: 0.9636 - val_precision: 0.7432 - val_recall: 0.7639 - learning_rate: 4.0000e-05
# Epoch 35/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8017 - auc: 0.8772 - loss: 0.8973 - precision: 0.7694 - recall: 0.7876 - val_accuracy: 0.7778 - val_auc: 0.8280 - val_loss: 0.9664 - val_precision: 0.7432 - val_recall: 0.7639 - learning_rate: 4.0000e-05
# Epoch 36/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8136 - auc: 0.8662 - loss: 0.9156 - precision: 0.7775 - recall: 0.8109 - val_accuracy: 0.7654 - val_auc: 0.8269 - val_loss: 0.9683 - val_precision: 0.7361 - val_recall: 0.7361 - learning_rate: 4.0000e-05
# Epoch 37/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8269 - auc: 0.8844 - loss: 0.8882 - precision: 0.7972 - recall: 0.8154 - val_accuracy: 0.7716 - val_auc: 0.8303 - val_loss: 0.9737 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 4.0000e-05
# Epoch 38/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8166 - auc: 0.8924 - loss: 0.8757 - precision: 0.7825 - recall: 0.8097 - val_accuracy: 0.7778 - val_auc: 0.8328 - val_loss: 0.9756 - val_precision: 0.7432 - val_recall: 0.7639 - learning_rate: 8.0000e-06
# Epoch 39/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8101 - auc: 0.8831 - loss: 0.8885 - precision: 0.7679 - recall: 0.8173 - val_accuracy: 0.7716 - val_auc: 0.8327 - val_loss: 0.9789 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 8.0000e-06
# Epoch 40/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.8123 - auc: 0.8861 - loss: 0.8840 - precision: 0.7700 - recall: 0.8188 - val_accuracy: 0.7716 - val_auc: 0.8338 - val_loss: 0.9784 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 8.0000e-06
# Epoch 41/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.7980 - auc: 0.8797 - loss: 0.8947 - precision: 0.7556 - recall: 0.8057 - val_accuracy: 0.7716 - val_auc: 0.8296 - val_loss: 0.9780 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 8.0000e-06
# Epoch 42/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.8156 - auc: 0.8894 - loss: 0.8730 - precision: 0.7763 - recall: 0.8198 - val_accuracy: 0.7716 - val_auc: 0.8313 - val_loss: 0.9787 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 43/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8224 - auc: 0.8886 - loss: 0.8776 - precision: 0.7938 - recall: 0.8081 - val_accuracy: 0.7716 - val_auc: 0.8309 - val_loss: 0.9807 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 44/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8096 - auc: 0.8810 - loss: 0.8906 - precision: 0.7619 - recall: 0.8282 - val_accuracy: 0.7716 - val_auc: 0.8305 - val_loss: 0.9811 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 45/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8134 - auc: 0.8835 - loss: 0.8866 - precision: 0.7741 - recall: 0.8152 - val_accuracy: 0.7716 - val_auc: 0.8306 - val_loss: 0.9816 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 46/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8182 - auc: 0.8891 - loss: 0.8785 - precision: 0.7711 - recall: 0.8377 - val_accuracy: 0.7716 - val_auc: 0.8323 - val_loss: 0.9821 - val_precision: 0.7397 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 47/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.7810 - auc: 0.8874 - loss: 0.8810 - precision: 0.7358 - recall: 0.7876 - val_accuracy: 0.7778 - val_auc: 0.8293 - val_loss: 0.9839 - val_precision: 0.7432 - val_recall: 0.7639 - learning_rate: 5.0000e-06
# Epoch 48/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8290 - auc: 0.8878 - loss: 0.8793 - precision: 0.7923 - recall: 0.8308 - val_accuracy: 0.7654 - val_auc: 0.8271 - val_loss: 0.9852 - val_precision: 0.7297 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 49/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.7924 - auc: 0.8710 - loss: 0.9025 - precision: 0.7590 - recall: 0.7768 - val_accuracy: 0.7654 - val_auc: 0.8254 - val_loss: 0.9882 - val_precision: 0.7297 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 50/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.7914 - auc: 0.8738 - loss: 0.9030 - precision: 0.7548 - recall: 0.7818 - val_accuracy: 0.7654 - val_auc: 0.8257 - val_loss: 0.9900 - val_precision: 0.7297 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 51/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8217 - auc: 0.8796 - loss: 0.8911 - precision: 0.7662 - recall: 0.8585 - val_accuracy: 0.7593 - val_auc: 0.8269 - val_loss: 0.9904 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 52/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.8243 - auc: 0.8802 - loss: 0.8929 - precision: 0.7920 - recall: 0.8182 - val_accuracy: 0.7593 - val_auc: 0.8259 - val_loss: 0.9920 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 53/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8214 - auc: 0.8811 - loss: 0.8847 - precision: 0.7862 - recall: 0.8184 - val_accuracy: 0.7593 - val_auc: 0.8233 - val_loss: 0.9934 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 54/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8267 - auc: 0.8895 - loss: 0.8707 - precision: 0.7849 - recall: 0.8373 - val_accuracy: 0.7593 - val_auc: 0.8271 - val_loss: 0.9908 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 55/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8178 - auc: 0.8879 - loss: 0.8799 - precision: 0.7736 - recall: 0.8309 - val_accuracy: 0.7593 - val_auc: 0.8282 - val_loss: 0.9896 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 56/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8183 - auc: 0.8891 - loss: 0.8777 - precision: 0.7694 - recall: 0.8410 - val_accuracy: 0.7593 - val_auc: 0.8292 - val_loss: 0.9891 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 57/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8165 - auc: 0.8825 - loss: 0.8859 - precision: 0.7842 - recall: 0.8075 - val_accuracy: 0.7593 - val_auc: 0.8269 - val_loss: 0.9896 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 58/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8268 - auc: 0.8949 - loss: 0.8682 - precision: 0.7879 - recall: 0.8329 - val_accuracy: 0.7593 - val_auc: 0.8298 - val_loss: 0.9904 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 59/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8240 - auc: 0.8791 - loss: 0.8922 - precision: 0.7837 - recall: 0.8324 - val_accuracy: 0.7593 - val_auc: 0.8282 - val_loss: 0.9906 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 60/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.7908 - auc: 0.8811 - loss: 0.8877 - precision: 0.7390 - recall: 0.8168 - val_accuracy: 0.7593 - val_auc: 0.8292 - val_loss: 0.9897 - val_precision: 0.7260 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 61/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8233 - auc: 0.8949 - loss: 0.8694 - precision: 0.7862 - recall: 0.8239 - val_accuracy: 0.7531 - val_auc: 0.8272 - val_loss: 0.9901 - val_precision: 0.7162 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 62/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8168 - auc: 0.8788 - loss: 0.8933 - precision: 0.7926 - recall: 0.7935 - val_accuracy: 0.7654 - val_auc: 0.8252 - val_loss: 0.9908 - val_precision: 0.7297 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 63/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 360ms/step - accuracy: 0.8201 - auc: 0.8982 - loss: 0.8610 - precision: 0.7719 - recall: 0.8440 - val_accuracy: 0.7654 - val_auc: 0.8276 - val_loss: 0.9899 - val_precision: 0.7237 - val_recall: 0.7639 - learning_rate: 5.0000e-06
# Epoch 64/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8327 - auc: 0.8950 - loss: 0.8628 - precision: 0.7842 - recall: 0.8575 - val_accuracy: 0.7531 - val_auc: 0.8282 - val_loss: 0.9902 - val_precision: 0.7105 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 65/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8189 - auc: 0.8864 - loss: 0.8799 - precision: 0.7842 - recall: 0.8143 - val_accuracy: 0.7531 - val_auc: 0.8242 - val_loss: 0.9910 - val_precision: 0.7105 - val_recall: 0.7500 - learning_rate: 5.0000e-06
# Epoch 66/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8229 - auc: 0.8896 - loss: 0.8776 - precision: 0.7809 - recall: 0.8343 - val_accuracy: 0.7531 - val_auc: 0.8248 - val_loss: 0.9927 - val_precision: 0.7051 - val_recall: 0.7639 - learning_rate: 5.0000e-06
# Epoch 67/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 361ms/step - accuracy: 0.8223 - auc: 0.8940 - loss: 0.8671 - precision: 0.7860 - recall: 0.8216 - val_accuracy: 0.7593 - val_auc: 0.8236 - val_loss: 0.9913 - val_precision: 0.7143 - val_recall: 0.7639 - learning_rate: 5.0000e-06
# Epoch 68/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.7941 - auc: 0.8823 - loss: 0.8857 - precision: 0.7456 - recall: 0.8121 - val_accuracy: 0.7531 - val_auc: 0.8263 - val_loss: 0.9904 - val_precision: 0.7162 - val_recall: 0.7361 - learning_rate: 5.0000e-06
# Epoch 69/150
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 8s 362ms/step - accuracy: 0.8119 - auc: 0.8676 - loss: 0.9087 - precision: 0.7756 - recall: 0.8081 - val_accuracy: 0.7469 - val_auc: 0.8273 - val_loss: 0.9889 - val_precision: 0.7123 - val_recall: 0.7222 - learning_rate: 5.0000e-06
# --- 1D CNN Training Finished ---

# %% [markdown]
# # **Model Evaluation**

# %%
print("\n--- Evaluating 1D CNN Model on Test Set ---")

# Loading the best CNN model saved by the callback
best_cnn_model = keras.models.load_model("best_cnn1d_model_CTZ.keras")

# --- Making Predictions on the Test Set ---
# Getting probabilities for AUC and ROC curve
y_pred_probs_cnn = best_cnn_model.predict(X_test, verbose=0).ravel()
# Getting class predictions (using default 0.5 threshold) for other metrics
y_pred_classes_cnn = (y_pred_probs_cnn > 0.5).astype(int)

# --- Calculating All Metrics ---
accuracy_cnn = accuracy_score(y_test, y_pred_classes_cnn)
auc_cnn = roc_auc_score(y_test, y_pred_probs_cnn)
kappa_cnn = cohen_kappa_score(y_test, y_pred_classes_cnn)
mcc_cnn = matthews_corrcoef(y_test, y_pred_classes_cnn)

print(f"\nOverall Performance Metrics (Test Set):")
print(f"Accuracy: {accuracy_cnn:.4f}")
print(f"AUC Score: {auc_cnn:.4f}")
print(f"Cohen's Kappa: {kappa_cnn:.4f}")
print(f"Matthews Correlation Coefficient (MCC): {mcc_cnn:.4f}")

# --- Classification Report ---
print("\nClassification Report:")
report_cnn = classification_report(
    y_test,
    y_pred_classes_cnn,
    target_names=["Susceptible (0)", "Resistant (1)"],
    digits=4
)
print(report_cnn)

# --- Confusion Matrix ---
print("\nConfusion Matrix:")
cm_cnn = confusion_matrix(y_test, y_pred_classes_cnn)
plt.figure(figsize=(6, 5))
sns.heatmap(cm_cnn, annot=True, fmt='d', cmap='Greens',
            xticklabels=["Susceptible", "Resistant"],
            yticklabels=["Susceptible", "Resistant"])
plt.ylabel('Actual')
plt.xlabel('Predicted')
#plt.title(f'Confusion Matrix - {TARGET_ANTIBIOTIC} (1D CNN)')
plt.show()

# --- ROC Curve ---
fpr_cnn, tpr_cnn, _ = roc_curve(y_test, y_pred_probs_cnn)
plt.figure(figsize=(7, 6))
plt.plot(fpr_cnn, tpr_cnn, color='green', lw=2, label=f'ROC curve (AUC = {auc_cnn:.4f})')
plt.plot([0, 1], [0, 1], color='gray', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
#plt.title(f'ROC Curve - {TARGET_ANTIBIOTIC} (1D CNN)')
plt.legend(loc="lower right")
plt.grid(alpha=0.3)
plt.show()
# Out:
# --- Evaluating 1D CNN Model on Test Set ---
#
# Overall Performance Metrics (Test Set):
# Accuracy: 0.7840
# AUC Score: 0.8375
# Cohen's Kappa: 0.5643
# Matthews Correlation Coefficient (MCC): 0.5647
#
# Classification Report:
#                  precision    recall  f1-score   support
#
# Susceptible (0)     0.8161    0.7889    0.8023        90
#   Resistant (1)     0.7467    0.7778    0.7619        72
#
#        accuracy                         0.7840       162
#       macro avg     0.7814    0.7833    0.7821       162
#    weighted avg     0.7852    0.7840    0.7843       162
#
#
# Confusion Matrix:
